# %% [markdown]
# ## A step-by-step guide to Data Visualizations in Python
#
# Follow along with [this article](https://medium.com/codex/step-by-step-guide-to-data-visualizations-in-python-b322129a1540).  We will be using [this .xlsx dataset](https://www.kaggle.com/roshansharma/immigration-to-canada-ibm-dataset) from Kaggle on Immigration to Canada from 1980–2013. No need to dowload it, it is already in the git repositroy you forked.<br>
#
# #### We suggest that instead of copy and pasting the code, you type it out.  This will help you become more familiar with the syntex and better understand it.

# %% [markdown]
# ### Step-1: Importing Packages

# %%
#import all librarys and modules needed
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
from matplotlib import style
#this sets the styles for our graphs
style.use('ggplot')
plt.rcParams['figure.figsize'] = (20,10)

# %% [markdown]
# ### Step-2 : Importing and Cleaning Data

# %%
#import and clean data, remember path is data/Canada.xlsx
df = pd.read_excel('/Users/mackaroni/Desktop/launchcode/LC_Exercises/DataVisualPython/Data/Canada.xlsx', 1, skiprows = range(20), skipfooter = 2)
df.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...  1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...  3616  3626  4807
# 3        Polynesia  902  Developing regions     0  ...     0     0     1
# 4  Southern Europe  901   Developed regions     0  ...     0     0     1
#
#    2007  2008  2009  2010  2011  2012  2013
# 0  2652  2111  1746  1758  2203  2635  2004
# 1   702   560   716   561   539   620   603
# 2  3623  4005  5393  4752  4325  3774  4331
# 3     0     0     0     0     0     0     0
# 4     1     0     0     0     0     1     1
#
# [5 rows x 43 columns]

# %%
#dropping columns
df.drop(['AREA', 'REG', 'DEV', 'Type', 'Coverage', 'DevName'], axis=1, inplace=True)
#renaming columns
df.rename(columns = {'OdName':'country', 'AreaName':'continent', 'RegName':'region'}, inplace=True)
#making new column called total which is the sum of axis 1 (columns)?
df['total'] = df.sum(axis=1)
#set index to countries
df = df.set_index('country')
#renaming index
df.rename(index ={'United Kingdom of Great Britain and Northern Ireland':'UK & Ireland'}, inplace=True)
#converting column types to strings
df.columns = df.columns.astype(str)
#useful for upcoming visuals
years = list(map(str, range(1980,2013)))
# Out:
# /var/folders/jf/znrk46b94vvg_z3sbflc39lc0000gn/T/ipykernel_4127/2297932883.py:6: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df['total'] = df.sum(axis=1)

# %% [markdown]
# ### Step-3 : Creating Beautiful Visualizations
#
# #### Line Chart

# %%
# Single line chart
#locate instances of 'haiti' and the corresponding years for plot

fig1 = df.loc['Haiti', years].plot(kind = 'line', color = 'r')
plt.title('Immigration from Haiti to Canada from 1980-2013',color = 'black')
plt.xlabel('Years',color = 'black')
plt.ylabel('Number of Immigrants',color = 'black')
plt.xticks(color = 'black')
plt.yticks(color = 'black')
plt.savefig('linechart_single.png')

plt.show()

# %%
# Multiple Line chart 
plt.style.use('dark_background')
fig2 = plt.plot(df.loc['India',years], label = 'India')
plt.plot(df.loc['China',years], label = 'China')
plt.plot(df.loc['Philippines',years], label = 'Sri Lanka')
plt.legend(loc = 'lower right', fontsize = 12)
plt.xticks(rotation = 80, color ='white')
plt.yticks(color ='white')
plt.title('Immigration to Canada from 1980-2013', color ='yellow', fontweight='bold')
plt.xlabel('Year', color='white')
plt.ylabel('Number of Immigrants', color ='white')
plt.savefig('linechart_multiple.png')
plt.show()

# %% [markdown]
# #### Lets talk about style

# %%
#Shows all avaiable built-in styles
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# To see a visualization of the aviable style sheets [click here](https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html).
#
# Syntex to select a specific style is: plt.style.use('style_name')
#
# Try it out by adding the line of code to the top of the code block above and choose one of the preinstalled styles. Which style is your favorite? dark_background! ...gotta love a darkmode moment <br><br>
#
# What happens when you change the line- plt.legend(loc = 'upper left', fontsize = 12) to plt.legend(loc = 'lower right', fontsize = 12)? the legend changes places/font size changes <br><br><br><br>
#
#
#
# Experiment changing other lines of the code and see how the graph changes. Add any notes or observations here. Going forward feel free to experiment with each graph type. xticks rotation changes how the line lables are oriented.<br><br><br><br><br><br>

# %% [markdown]
# #### Install mplcyberpunk
# Open a terminal window and at at the prompt type:
#
# python -V
#
# If its python 3.something, copy and paste: pip install mplcyberpunk
# If its python 2.something, copy and paste: pip3 install mplcyberpunk
#
#
# For more info on mplcyberpunk click [here.](https://github.com/dhaitz/mplcyberpunk)

# %%
# Cyberpunk Multiple Line Chart
import mplcyberpunk
style.use('cyberpunk')

plt.plot(df.loc['India',years], label = 'India')
plt.plot(df.loc['China',years], label = 'China')
plt.plot(df.loc['Philippines',years], label = 'Sri Lanka')
plt.legend(loc= 'upper left', fontsize=14)
plt.xticks(rotation = 90, color = 'white', fontsize = 14, fontweight = 'bold')
plt.yticks(color = 'white', fontsize = 14, fontweight = 'bold')
plt.title('Immigration to Canada from 1980-2013',color = 'white', fontsize = 20, fontweight = 'bold')
plt.xlabel('Year',color = 'white', fontsize = 16, fontweight = 'bold')
plt.ylabel('Number of Immigrants',color = 'white',fontsize = 16, fontweight = 'bold')
plt.savefig('cyber_line.png')

plt.show()

# %% [markdown]
# #### Bar Chart

# %%
# Vertical bar chart
# Do not change the style back to ggplot 
# delete the style.use('ggplot') line of code
df_tot = pd.DataFrame(df.loc[:,years].sum())
df_tot.rename(columns = {0:'total'}, inplace = True)

df_tot.plot(kind = 'bar', legend = False)
plt.title('Total Immigrants to Canada from 1980-2013',color = 'white', fontsize=20, fontweight = 'bold')
plt.xticks(color = 'white',fontsize=14, fontweight = 'bold')
plt.yticks(color = 'white',fontsize=14, fontweight = 'bold')
plt.xlabel('Year',color = 'white',fontsize=16, fontweight = 'bold')
plt.ylabel('Number of Immigrants',color = 'white',fontsize=16, fontweight = 'bold')
plt.savefig('bar_vertical.png')

plt.show()

# %% [markdown]
# Notice that style is still set to cyberpunk.  How do we fix it so we can see the labels?<br> <br>
#
# Answer: change the color = 'black' to 'white'
#
# Feel free to experiment and add any notes or observations here.
# I changed the size and font weight of all the labels<br><br><br><br><br>

# %%
# Horizontal bar chart
#change style back to ggplt
style.use('ggplot')
df_top10 = pd.DataFrame(df.nlargest(10,'total')['total'].sort_values(ascending = True))

df_top10.plot.barh(legend = False, color = 'grey', edgecolor = 'green')
plt.title('Top 10 Immigrant Countries to Canada from 1980-2013',color = 'black', fontsize=18, fontweight='bold')
plt.xlabel('Number of Immigrants',color = 'black',fontsize=16, fontweight='bold')
plt.ylabel('Country',color = 'black', fontsize=16, fontweight='bold')
plt.xticks(color = 'black', rotation=45, fontsize=14)
plt.yticks(color = 'black', fontsize=14)
plt.savefig('bar_horizontal.png')

plt.show()

# %% [markdown]
# Feel free to experiment and add any notes or observations here. <br><br><br><br><br>

# %%
# Grouped bar chart
year_int10 = list(map(str, (1980,1990,2000,2010, 2013)))
df_group = pd.DataFrame(df.loc[['India','China','Philippines','Pakistan'],year_int10].T)

df_group.plot.bar(edgecolor = 'white')
plt.title('Total Immigrants to Canada from 1980-2013',color = 'black', fontsize = 18, fontweight='bold')
plt.xticks(color = 'black', rotation=0,fontsize = 16)
plt.yticks(color = 'black',fontsize = 16)
plt.xlabel('Year',color = 'black', fontsize = 16, fontweight='bold')
plt.ylabel('Number of Immigrants',color = 'black', fontsize = 16, fontweight='bold')
plt.legend(loc='upper left', title ='Country', fontsize = 12, labelcolor='black')
plt.savefig('bar_grouped.png')

plt.show()

# %% [markdown]
# Notice how the labels in the legend have disapeared?  We can fix this by adding labelcolor='k' to plt.legend<br>
# <br>plt.legend(title = 'Country', fontsize = 12, labelcolor='black')

# %% [markdown]
# Feel free to experiment and add any notes or observations here.
# little changes in size, fontweight, rotation of labels, etc make such a big difference in readability of charts and visual appeal.<br><br><br><br><br>

# %% [markdown]
# #### Area Chart

# %%
# Area Chart
plt.fill_between(df_tot.index, df_tot['total'], color='coral', alpha=0.2)
plt.plot(df_tot.index, df_tot['total'], color='Slateblue', alpha=1)
plt.title('Total Immigrants to Canada from 1980-2013', fontsize = 18, color = 'black')
plt.yticks(fontsize = 12, color = 'black')
plt.xticks(fontsize = 12, rotation = 90, color = 'black')
plt.xlabel('Year', fontsize = 14, color = 'black')
plt.ylabel('Number of Immigrants', fontsize = 14, color = 'black')
plt.savefig('area_simple.png')

# %% [markdown]
# Feel free to experiment and add any notes or observations here. <br><br><br><br><br>

# %%
# cyberpunk simple area chart
style.use('cyberpunk')

plt.fill_between(df_tot.index, df_tot['total'], color = 'violet', alpha = 0.1)
plt.plot(df_tot.index, df_tot['total'], color = 'violet', alpha = 1)
mplcyberpunk.add_glow_effects()
plt.title('Total Immigrants to Canada from 1980-2013', fontsize = 20,fontweight = 'bold', color = 'white')
plt.yticks(fontsize = 14, color = 'white',fontweight = 'bold')
plt.xticks(fontsize = 14, rotation = 90, color = 'white',fontweight = 'bold')
plt.xlabel('Year', fontsize = 16, color = 'white',fontweight = 'bold')
plt.ylabel('Number of Immigrants', fontsize = 16, color = 'white',fontweight = 'bold')
plt.savefig('cyber_area_simple.png')

plt.show()

# %% [markdown]
# Feel free to experiment and add any notes or observations here.
# alpha changes the transparency
# <br><br><br><br><br>

# %%
# stacked area chart
style.use('ggplot')

color = ['skyblue','lightcoral']
top2_list = df.nlargest(2, 'total').index.tolist()
df_top2 = pd.DataFrame(df.loc[top2_list, years].T)

df_top2.plot(kind = 'area', stacked = True, color = color, alpha=0.5)
plt.title('Total Immigrants to Canada from 1980-2013',color = 'black')
plt.legend(loc= 'upper left', title = 'Country', labelcolor='black',fontsize = 12)
plt.xlabel('Year',color = 'black')
plt.ylabel('Number of Immigrants',color = 'black')
plt.xticks(color = 'black')
plt.yticks(color = 'black')
plt.savefig('area_stacked.png')

plt.show()

# %% [markdown]
# Feel free to experiment and add any notes or observations here. you can add alpha action to plot to change transparancy for readability <br><br><br><br><br>

# %%
# unstacked area chart

df_top2.plot(kind = 'area', stacked = False, color = color, alpha=0.4)
plt.title('Total Immigrants to Canada from 1980-2013',color = 'black')
plt.xlabel('Year',color = 'black')
plt.ylabel('Number of Immigrants',color = 'black')
plt.legend(labelcolor='black',fontsize = 12)
plt.xticks(color = 'black')
plt.yticks(color = 'black')
plt.savefig('area_unstacked.png')

plt.show()

# %% [markdown]
# Feel free to experiment and add any notes or observations here. <br><br><br><br><br>

# %% [markdown]
# #### Box Plot

# %%
# Vertical Box Plot
df_box = pd.DataFrame(df.loc[['India','China','Pakistan','UK & Ireland','Philippines'], years].T)
plt.style.use('dark_background')
df_box.plot(kind='box', color='Lightgreen')
plt.title('Top 5 Immigrant Countries to Canada from 1980-2013', color ='white', fontsize=20, fontweight='bold')
plt.xlabel('Country', color='white',fontsize=16)
plt.ylabel('Number of Immigrants', color='white',fontsize=16)
plt.xticks(color = 'white', fontsize=14)
plt.yticks(color = 'white', fontsize=14)
plt.savefig('box_vertical.png')

plt.show()

# %% [markdown]
# Feel free to experiment and add any notes or observations here. <br><br><br><br><br>

# %%
# horizontal box plot
plt.style.use('ggplot')
df_box.plot(kind='box', vert=False, color='black')
plt.title('Top 5 Immigrant Countries to Canada from 1980-2013', color ='black', fontsize=20, fontweight='bold')
plt.xlabel('Number of Immigrants', color='black',fontsize=16, fontweight='bold')
plt.ylabel('Country', color='black',fontsize=16,fontweight='bold')
plt.xticks(color = 'black', fontsize=14)
plt.yticks(color = 'black', fontsize=14)
plt.savefig('box_vertical.png')

plt.show()

# %% [markdown]
# Feel free to experiment and add any notes or observations here. the only difference here is that we added vert=False to the initial boxplot call <br><br><br><br><br>

# %% [markdown]
# #### Scatter Plot
#
# With the newist version of Seaborn we have to specify x and y.
#
# example: sb.scatterplot(x = 'sepal_length', y = 'sepal_width', data = df_iris)

# %%
#scatter plot comparing sepal length to sepal width
df_iris = sb.load_dataset('iris')
sb.set(font_scale=2)
sb.scatterplot(x='sepal_length',y='sepal_width', data= df_iris, s =200, linewidth =3, edgecolor='black')
plt.title('Scatter Plot Sample', color ='black', fontsize=24)
plt.savefig('scatter.png')

plt.show()

# %% [markdown]
# Feel free to experiment and add any notes or observations here.
#
# s = size of dot, line width = width of line around dot. sb.set(font_scale=2)--made the labels larger and easier to read<br><br><br>

# %% [markdown]
# #### Histogram
#
# With the newist version of Seaborn they have deprecated distplot. Replace distplot with histplot and add kde = True
#
# example:
# sb.histplot(df_iris['sepal_length'], color = 'Red', label = 'Sepal Length', kde = True)

# %%
#Histogram side by side, with kde
df_iris = sb.load_dataset('iris')
sb.histplot(df_iris['sepal_length'],color='seagreen', label ='Sepal Length', kde=True)
sb.histplot(df_iris['sepal_width'], color='mediumorchid', label='Sepal Width', kde=True)
plt.legend(fontsize=14)
plt.xlabel('Sepal Width', color='black')
plt.ylabel('Frequency', color='black')
plt.xticks(color='black')
plt.yticks(color='black')
plt.savefig('histogram.png')
            
plt.show()

# %% [markdown]
# Feel free to experiment and add any notes or observations here.
# kernel density estimation (KDE) is the application of kernel smoothing for probability density estimation... (when set to True it gives us the line over the bars)<br><br><br><br><br>

# %% [markdown]
# #### Bubble Plot

# %%
# Bubble Plot
x= np.random.rand(1,30,1)
y= np.random.rand(1,30,1)
size= np.random.rand(1,30,1)

plt.scatter(x,y,s = size*4000, alpha= 0.4, color = 'cornflowerblue', edgecolor = 'royalblue', linewidth=4)
plt.title('Bubble Plot Sample', color= 'black', fontsize=18)
plt.savefig('bubble.png')

plt.show()

# %% [markdown]
# Feel free to experiment and add any notes or observations here. <br><br><br><br><br>

# %% [markdown]
# #### Pie Chart
#
# Skip this one as the code throws an error.

# %% [markdown]
# df_pie = pd.DataFrame(df.groupby('continent')['total'].sum().T)
# colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen', 'pink']
# explode = [0,0.1,0,0,0.1,0.1]
#
# plt.pie(df_pie, colors = colors, autopct = '%1.1f%%', startangle = 90, explode = explode, pctdistance = 1.12, shadow = True)
# plt.title('Continent-Wise Immigrants Distribution', color = 'black', y = 1.1, fontsize = 18)
# plt.legend(df_pie.index, loc = 'upper left', fontsize = 12)
# plt.axis('equal')
# plt.savefig('pie.png')
#
# plt.show()

# %% [markdown]
# #### Doughnut Chart

# %%
# Doughnut Chart
top5_list = df.nlargest(5, 'total').index.tolist()
df_top5 = pd.DataFrame(df.loc[top5_list, 'total'].T)
circle = plt.Circle((0,0), 0.5, color='white')
colors = ['gold', 'coral', 'olivedrab','firebrick','darkcyan','mediumpurple']

plt.pie(df_top5['total'], autopct = '%1.1f%%', shadow=True, explode = [0.2,0,0,0,0], colors=colors, startangle=0)
fig= plt.gcf()
fig.gca().add_artist(circle)
plt.legend(df_top5.index, fontsize= 12, loc= 'upper left')
plt.title('Top 5 Immigrant Country Distribution', color='black', fontsize=18)
plt.axis('equal')
plt.savefig('doughnut.png')

plt.show()

# %% [markdown]
# Feel free to experiment and add any notes or observations here.
#
# explode = is the breakaway bit of the doughnut. you can adjust what pieces move and by how much.
#
# you can adjust the width of the doughnut on the circle = line
#
# startangle rotates the plot<br><br><br><br><br>

# %% [markdown]
# #### Regression Plot

# %%
# Strong trend
df_reg = pd.DataFrame(df.loc['China',years])
df_reg.reset_index(inplace=True)
df_reg.rename(columns = {'index':'year'}, inplace=True)
df_reg[['year','China']]= df_reg[['year','China']].astype(int)
                         
sb.regplot(x='year', y='China', data= df_reg, color='blue', scatter_kws = {'s':250, 'alpha':0.4})
plt.title('Total Immigration from China to Canada from 1980-2013', color = 'black')
plt.xlabel('year', color= 'black')
plt.ylabel('number of immigrants', color= 'black')
plt.xticks(color='black')
plt.yticks(color='black')
plt.savefig('reg_strong.png')

plt.show()

# %% [markdown]
# Feel free to experiment and add any notes or observations here. <br><br><br><br><br>

# %%
# Weak trend
df_reg1 = pd.DataFrame(df.loc[['Denmark','Norway','Sweden'],years].sum())
df_reg1.reset_index(inplace = True)
df_reg1.rename(columns = {'index':'year',0:'total'}, inplace = True)
df_reg1[['year','total']] = df_reg1[['year','total']].astype(int)

sb.regplot(x='year', y='total', data=df_reg1, color='green', scatter_kws={'s':200, 'alpha':0.5})
plt.title('Total Immigrants from Scandinavia to Canada from 1980-2013', color = 'black')
plt.xticks(color = 'black')
plt.yticks(color = 'black')
plt.xlabel('Year', color = 'black')
plt.ylabel('Number of Immigrants', color = 'black')
plt.savefig('reg_weak.png')

# %% [markdown]
# Feel free to experiment and add any notes or observations here. <br><br><br><br><br>

# %% [markdown]
# #### Word Cloud
#
# You might need to pip install wordcloud and pip install Pywaffle.  Follow the instruction from when you installed cyperpunk earlier.
#
# Make sure to add the txt files from [here](https://github.com/codinglikeagirl42/DataVisualizationPython) to your data folder and remember the path is data/filename.txt. Try creating your own txt file to visualize.

# %%
# word cloud
from wordcloud import WordCloud, STOPWORDS
text = open('/Users/mackaroni/Desktop/launchcode/LC_Exercises/DataVisualPython/Data/chattahoochee.txt','r', encoding = 'utf-8').read()
stopwords = set(STOPWORDS)
wordcloud = WordCloud(background_color = 'black',colormap='Pastel1', max_words = 400, stopwords = stopwords)

wordcloud.generate(text)
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.savefig('wordcloud.png')

plt.show()

# %% [markdown]
# Feel free to experiment and add any notes or observations here. <br><br><br><br><br>

# %% [markdown]
# #### Lollipop Chart

# %%
# Lollipop chart
plt.stem(df_tot.index, df_tot['total'])
plt.title('total immigrants to canada from canada 1980-2013', color='black')
plt.xlabel('year', color='black')
plt.ylabel('number of immigrants',color='black')
plt.xticks(color = 'black', fontsize=12, rotation=90)
plt.yticks(color = 'black', fontsize=12)
plt.savefig('lollipop.png')

plt.show()

# %% [markdown]
# Feel free to experiment and add any notes or observations here. <br><br><br><br><br>
